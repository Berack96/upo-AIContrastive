# %%
import sys

#install torch and torchvision if not already installed
# !{sys.executable} -m pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

import torch.nn as nn
import torch, torchvision
import torch.nn.functional as F
import regex as re
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (2.7.0+cu128)
# Requirement already satisfied: torchvision in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (0.22.0+cu128)
# Requirement already satisfied: torchaudio in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (2.7.0+cu128)
# Requirement already satisfied: filelock in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from torch) (4.12.2)
# Requirement already satisfied: setuptools in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from torch) (70.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from torch) (2024.6.1)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.61 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from torch) (12.8.61)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.57 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from torch) (12.8.57)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.57 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from torch) (12.8.57)
# Requirement already satisfied: nvidia-cudnn-cu12==9.7.1.26 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from torch) (9.7.1.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.3.14 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from torch) (12.8.3.14)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.41 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from torch) (11.3.3.41)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.55 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from torch) (10.3.9.55)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.2.55 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from torch) (11.7.2.55)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.7.53 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from torch) (12.5.7.53)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.3 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from torch) (0.6.3)
# Requirement already satisfied: nvidia-nccl-cu12==2.26.2 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from torch) (2.26.2)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.55 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from torch) (12.8.55)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.61 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from torch) (12.8.61)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.0.11 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from torch) (1.13.0.11)
# Requirement already satisfied: triton==3.3.0 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from torch) (3.3.0)
# Requirement already satisfied: numpy in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from torchvision) (2.1.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from torchvision) (11.0.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from jinja2->torch) (2.1.5)

# %%
class DenseNet121(nn.Module):
    """Model modified.
    The architecture of our model is the same as standard DenseNet121
    except the classifier layer which has an additional sigmoid function.
    """
    def __init__(self, out_size):
        super(DenseNet121, self).__init__()
        self.densenet121 = torchvision.models.densenet121(pretrained=True)
        # embeddings
        num_ftrs = self.densenet121.classifier.in_features
        self.densenet121.classifier = nn.Sequential(
            nn.Linear(num_ftrs, out_size),
            nn.Sigmoid()
        )

    def forward(self, x):
        x = self.densenet121(x)
        return x


model = DenseNet121(14).cuda()

modelCheckpoint = torch.load("../models/chexnet.pth.tar")
pattern = re.compile(r'^(.*denselayer\d+\.(?:norm|relu|conv))\.((?:[12])\.(?:weight|bias|running_mean|running_var))$')
state_dict = modelCheckpoint['state_dict']
for i, key in enumerate(list(state_dict.keys())):
    res = pattern.match(key)

    if res:
        new_key = (res.group(1) + res.group(2))[7:]
        state_dict[new_key] = state_dict[key]
        del state_dict[key]
    else:
        new_key = key[7:]
        state_dict[new_key] = state_dict[key]
        del state_dict[key]
model.load_state_dict(state_dict, strict=False)
# Out:
# /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=DenseNet121_Weights.IMAGENET1K_V1`. You can also use `weights=DenseNet121_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# <All keys matched successfully>

# %%
# !{sys.executable} -m pip install onnx onnx2keras onnxruntime jax

input_data = torch.randn(1, 3, 224, 224).cuda()
torch.onnx.export(
    model,
    input_data,
    "densenet121.onnx",
    export_params=True,
    opset_version=11,
    do_constant_folding=True,
    input_names=['input'],
    output_names=['output']
)
# Out:
# Requirement already satisfied: onnx in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (1.18.0)
# Requirement already satisfied: onnx2keras in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (0.0.24)
# Requirement already satisfied: onnxruntime in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (1.22.0)
# Collecting jax
#   Using cached jax-0.6.0-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: numpy>=1.22 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from onnx) (2.1.2)
# Requirement already satisfied: protobuf>=4.25.1 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from onnx) (5.29.4)
# Requirement already satisfied: typing_extensions>=4.7.1 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from onnx) (4.12.2)
# Requirement already satisfied: tensorflow in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from onnx2keras) (2.19.0)
# Requirement already satisfied: coloredlogs in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from onnxruntime) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from onnxruntime) (25.2.10)
# Requirement already satisfied: packaging in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from onnxruntime) (25.0)
# Requirement already satisfied: sympy in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from onnxruntime) (1.13.3)
# Collecting jaxlib<=0.6.0,>=0.6.0 (from jax)
#   Using cached jaxlib-0.6.0-cp312-cp312-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from jax) (0.5.1)
# Requirement already satisfied: opt_einsum in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from jax) (3.4.0)
# Collecting scipy>=1.11.1 (from jax)
#   Using cached scipy-1.15.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: humanfriendly>=9.1 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from coloredlogs->onnxruntime) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from sympy->onnxruntime) (1.3.0)
# Requirement already satisfied: absl-py>=1.0.0 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from tensorflow->onnx2keras) (2.2.2)
# Requirement already satisfied: astunparse>=1.6.0 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from tensorflow->onnx2keras) (1.6.3)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from tensorflow->onnx2keras) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from tensorflow->onnx2keras) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from tensorflow->onnx2keras) (18.1.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from tensorflow->onnx2keras) (2.32.3)
# Requirement already satisfied: setuptools in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from tensorflow->onnx2keras) (70.2.0)
# Requirement already satisfied: six>=1.12.0 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from tensorflow->onnx2keras) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from tensorflow->onnx2keras) (3.1.0)
# Requirement already satisfied: wrapt>=1.11.0 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from tensorflow->onnx2keras) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from tensorflow->onnx2keras) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from tensorflow->onnx2keras) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from tensorflow->onnx2keras) (3.9.2)
# Requirement already satisfied: h5py>=3.11.0 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from tensorflow->onnx2keras) (3.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow->onnx2keras) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow->onnx2keras) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow->onnx2keras) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from requests<3,>=2.21.0->tensorflow->onnx2keras) (2025.4.26)
# Requirement already satisfied: markdown>=2.6.8 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from tensorboard~=2.19.0->tensorflow->onnx2keras) (3.8)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from tensorboard~=2.19.0->tensorflow->onnx2keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from tensorboard~=2.19.0->tensorflow->onnx2keras) (3.1.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from astunparse>=1.6.0->tensorflow->onnx2keras) (0.45.1)
# Requirement already satisfied: rich in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow->onnx2keras) (14.0.0)
# Requirement already satisfied: namex in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow->onnx2keras) (0.0.9)
# Requirement already satisfied: optree in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from keras>=3.5.0->tensorflow->onnx2keras) (0.15.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow->onnx2keras) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow->onnx2keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from rich->keras>=3.5.0->tensorflow->onnx2keras) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow->onnx2keras) (0.1.2)
# Using cached jax-0.6.0-py3-none-any.whl (2.3 MB)
# Using cached jaxlib-0.6.0-cp312-cp312-manylinux2014_x86_64.whl (87.8 MB)
# Using cached scipy-1.15.3-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (37.3 MB)
# Installing collected packages: scipy, jaxlib, jax
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [jax]2/3 [jax]ib]
# Successfully installed jax-0.6.0 jaxlib-0.6.0 scipy-1.15.3

# %%
import os
os.environ["KERAS_BACKEND"] = "torch"

import onnx
onnx_model = onnx.load('densenet121.onnx')

from onnx2keras import onnx_to_keras
keras_model = onnx_to_keras(onnx_model, ['input'])

# Load weights into Keras model
weights = model.state_dict()
keras_model.set_weights([weights[key].numpy() for key in weights.keys()])

# Use Keras model for inference
output = keras_model.predict(input_data)
# Out:
# INFO:onnx2keras:Converter is called.
# DEBUG:onnx2keras:List input shapes:
# DEBUG:onnx2keras:None
# DEBUG:onnx2keras:List inputs:
# DEBUG:onnx2keras:Input 0 -> input.
# DEBUG:onnx2keras:List outputs:
# DEBUG:onnx2keras:Output 0 -> output.
# DEBUG:onnx2keras:Gathering weights to dictionary.
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock1.denselayer1.norm1.weight with shape (64,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock1.denselayer1.norm1.bias with shape (64,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock1.denselayer1.norm1.running_mean with shape (64,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock1.denselayer1.norm1.running_var with shape (64,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock1.denselayer1.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock1.denselayer2.norm1.weight with shape (96,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock1.denselayer2.norm1.bias with shape (96,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock1.denselayer2.norm1.running_mean with shape (96,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock1.denselayer2.norm1.running_var with shape (96,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock1.denselayer2.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock1.denselayer3.norm1.weight with shape (128,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock1.denselayer3.norm1.bias with shape (128,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock1.denselayer3.norm1.running_mean with shape (128,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock1.denselayer3.norm1.running_var with shape (128,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock1.denselayer3.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock1.denselayer4.norm1.weight with shape (160,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock1.denselayer4.norm1.bias with shape (160,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock1.denselayer4.norm1.running_mean with shape (160,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock1.denselayer4.norm1.running_var with shape (160,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock1.denselayer4.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock1.denselayer5.norm1.weight with shape (192,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock1.denselayer5.norm1.bias with shape (192,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock1.denselayer5.norm1.running_mean with shape (192,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock1.denselayer5.norm1.running_var with shape (192,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock1.denselayer5.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock1.denselayer6.norm1.weight with shape (224,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock1.denselayer6.norm1.bias with shape (224,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock1.denselayer6.norm1.running_mean with shape (224,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock1.denselayer6.norm1.running_var with shape (224,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock1.denselayer6.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.transition1.norm.weight with shape (256,).
# DEBUG:onnx2keras:Found weight densenet121.features.transition1.norm.bias with shape (256,).
# DEBUG:onnx2keras:Found weight densenet121.features.transition1.norm.running_mean with shape (256,).
# DEBUG:onnx2keras:Found weight densenet121.features.transition1.norm.running_var with shape (256,).
# DEBUG:onnx2keras:Found weight densenet121.features.transition1.conv.weight with shape (128, 256, 1, 1).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer1.norm1.weight with shape (128,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer1.norm1.bias with shape (128,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer1.norm1.running_mean with shape (128,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer1.norm1.running_var with shape (128,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer1.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer2.norm1.weight with shape (160,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer2.norm1.bias with shape (160,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer2.norm1.running_mean with shape (160,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer2.norm1.running_var with shape (160,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer2.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer3.norm1.weight with shape (192,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer3.norm1.bias with shape (192,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer3.norm1.running_mean with shape (192,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer3.norm1.running_var with shape (192,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer3.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer4.norm1.weight with shape (224,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer4.norm1.bias with shape (224,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer4.norm1.running_mean with shape (224,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer4.norm1.running_var with shape (224,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer4.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer5.norm1.weight with shape (256,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer5.norm1.bias with shape (256,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer5.norm1.running_mean with shape (256,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer5.norm1.running_var with shape (256,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer5.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer6.norm1.weight with shape (288,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer6.norm1.bias with shape (288,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer6.norm1.running_mean with shape (288,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer6.norm1.running_var with shape (288,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer6.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer7.norm1.weight with shape (320,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer7.norm1.bias with shape (320,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer7.norm1.running_mean with shape (320,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer7.norm1.running_var with shape (320,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer7.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer8.norm1.weight with shape (352,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer8.norm1.bias with shape (352,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer8.norm1.running_mean with shape (352,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer8.norm1.running_var with shape (352,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer8.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer9.norm1.weight with shape (384,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer9.norm1.bias with shape (384,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer9.norm1.running_mean with shape (384,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer9.norm1.running_var with shape (384,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer9.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer10.norm1.weight with shape (416,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer10.norm1.bias with shape (416,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer10.norm1.running_mean with shape (416,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer10.norm1.running_var with shape (416,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer10.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer11.norm1.weight with shape (448,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer11.norm1.bias with shape (448,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer11.norm1.running_mean with shape (448,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer11.norm1.running_var with shape (448,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer11.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer12.norm1.weight with shape (480,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer12.norm1.bias with shape (480,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer12.norm1.running_mean with shape (480,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer12.norm1.running_var with shape (480,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock2.denselayer12.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.transition2.norm.weight with shape (512,).
# DEBUG:onnx2keras:Found weight densenet121.features.transition2.norm.bias with shape (512,).
# DEBUG:onnx2keras:Found weight densenet121.features.transition2.norm.running_mean with shape (512,).
# DEBUG:onnx2keras:Found weight densenet121.features.transition2.norm.running_var with shape (512,).
# DEBUG:onnx2keras:Found weight densenet121.features.transition2.conv.weight with shape (256, 512, 1, 1).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer1.norm1.weight with shape (256,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer1.norm1.bias with shape (256,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer1.norm1.running_mean with shape (256,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer1.norm1.running_var with shape (256,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer1.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer2.norm1.weight with shape (288,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer2.norm1.bias with shape (288,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer2.norm1.running_mean with shape (288,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer2.norm1.running_var with shape (288,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer2.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer3.norm1.weight with shape (320,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer3.norm1.bias with shape (320,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer3.norm1.running_mean with shape (320,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer3.norm1.running_var with shape (320,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer3.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer4.norm1.weight with shape (352,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer4.norm1.bias with shape (352,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer4.norm1.running_mean with shape (352,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer4.norm1.running_var with shape (352,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer4.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer5.norm1.weight with shape (384,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer5.norm1.bias with shape (384,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer5.norm1.running_mean with shape (384,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer5.norm1.running_var with shape (384,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer5.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer6.norm1.weight with shape (416,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer6.norm1.bias with shape (416,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer6.norm1.running_mean with shape (416,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer6.norm1.running_var with shape (416,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer6.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer7.norm1.weight with shape (448,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer7.norm1.bias with shape (448,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer7.norm1.running_mean with shape (448,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer7.norm1.running_var with shape (448,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer7.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer8.norm1.weight with shape (480,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer8.norm1.bias with shape (480,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer8.norm1.running_mean with shape (480,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer8.norm1.running_var with shape (480,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer8.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer9.norm1.weight with shape (512,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer9.norm1.bias with shape (512,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer9.norm1.running_mean with shape (512,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer9.norm1.running_var with shape (512,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer9.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer10.norm1.weight with shape (544,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer10.norm1.bias with shape (544,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer10.norm1.running_mean with shape (544,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer10.norm1.running_var with shape (544,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer10.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer11.norm1.weight with shape (576,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer11.norm1.bias with shape (576,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer11.norm1.running_mean with shape (576,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer11.norm1.running_var with shape (576,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer11.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer12.norm1.weight with shape (608,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer12.norm1.bias with shape (608,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer12.norm1.running_mean with shape (608,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer12.norm1.running_var with shape (608,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer12.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer13.norm1.weight with shape (640,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer13.norm1.bias with shape (640,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer13.norm1.running_mean with shape (640,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer13.norm1.running_var with shape (640,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer13.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer14.norm1.weight with shape (672,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer14.norm1.bias with shape (672,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer14.norm1.running_mean with shape (672,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer14.norm1.running_var with shape (672,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer14.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer15.norm1.weight with shape (704,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer15.norm1.bias with shape (704,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer15.norm1.running_mean with shape (704,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer15.norm1.running_var with shape (704,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer15.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer16.norm1.weight with shape (736,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer16.norm1.bias with shape (736,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer16.norm1.running_mean with shape (736,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer16.norm1.running_var with shape (736,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer16.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer17.norm1.weight with shape (768,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer17.norm1.bias with shape (768,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer17.norm1.running_mean with shape (768,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer17.norm1.running_var with shape (768,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer17.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer18.norm1.weight with shape (800,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer18.norm1.bias with shape (800,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer18.norm1.running_mean with shape (800,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer18.norm1.running_var with shape (800,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer18.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer19.norm1.weight with shape (832,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer19.norm1.bias with shape (832,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer19.norm1.running_mean with shape (832,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer19.norm1.running_var with shape (832,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer19.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer20.norm1.weight with shape (864,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer20.norm1.bias with shape (864,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer20.norm1.running_mean with shape (864,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer20.norm1.running_var with shape (864,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer20.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer21.norm1.weight with shape (896,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer21.norm1.bias with shape (896,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer21.norm1.running_mean with shape (896,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer21.norm1.running_var with shape (896,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer21.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer22.norm1.weight with shape (928,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer22.norm1.bias with shape (928,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer22.norm1.running_mean with shape (928,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer22.norm1.running_var with shape (928,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer22.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer23.norm1.weight with shape (960,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer23.norm1.bias with shape (960,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer23.norm1.running_mean with shape (960,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer23.norm1.running_var with shape (960,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer23.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer24.norm1.weight with shape (992,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer24.norm1.bias with shape (992,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer24.norm1.running_mean with shape (992,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer24.norm1.running_var with shape (992,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock3.denselayer24.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.transition3.norm.weight with shape (1024,).
# DEBUG:onnx2keras:Found weight densenet121.features.transition3.norm.bias with shape (1024,).
# DEBUG:onnx2keras:Found weight densenet121.features.transition3.norm.running_mean with shape (1024,).
# DEBUG:onnx2keras:Found weight densenet121.features.transition3.norm.running_var with shape (1024,).
# DEBUG:onnx2keras:Found weight densenet121.features.transition3.conv.weight with shape (512, 1024, 1, 1).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer1.norm1.weight with shape (512,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer1.norm1.bias with shape (512,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer1.norm1.running_mean with shape (512,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer1.norm1.running_var with shape (512,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer1.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer2.norm1.weight with shape (544,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer2.norm1.bias with shape (544,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer2.norm1.running_mean with shape (544,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer2.norm1.running_var with shape (544,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer2.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer3.norm1.weight with shape (576,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer3.norm1.bias with shape (576,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer3.norm1.running_mean with shape (576,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer3.norm1.running_var with shape (576,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer3.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer4.norm1.weight with shape (608,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer4.norm1.bias with shape (608,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer4.norm1.running_mean with shape (608,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer4.norm1.running_var with shape (608,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer4.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer5.norm1.weight with shape (640,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer5.norm1.bias with shape (640,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer5.norm1.running_mean with shape (640,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer5.norm1.running_var with shape (640,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer5.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer6.norm1.weight with shape (672,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer6.norm1.bias with shape (672,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer6.norm1.running_mean with shape (672,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer6.norm1.running_var with shape (672,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer6.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer7.norm1.weight with shape (704,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer7.norm1.bias with shape (704,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer7.norm1.running_mean with shape (704,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer7.norm1.running_var with shape (704,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer7.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer8.norm1.weight with shape (736,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer8.norm1.bias with shape (736,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer8.norm1.running_mean with shape (736,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer8.norm1.running_var with shape (736,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer8.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer9.norm1.weight with shape (768,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer9.norm1.bias with shape (768,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer9.norm1.running_mean with shape (768,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer9.norm1.running_var with shape (768,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer9.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer10.norm1.weight with shape (800,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer10.norm1.bias with shape (800,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer10.norm1.running_mean with shape (800,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer10.norm1.running_var with shape (800,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer10.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer11.norm1.weight with shape (832,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer11.norm1.bias with shape (832,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer11.norm1.running_mean with shape (832,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer11.norm1.running_var with shape (832,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer11.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer12.norm1.weight with shape (864,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer12.norm1.bias with shape (864,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer12.norm1.running_mean with shape (864,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer12.norm1.running_var with shape (864,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer12.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer13.norm1.weight with shape (896,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer13.norm1.bias with shape (896,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer13.norm1.running_mean with shape (896,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer13.norm1.running_var with shape (896,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer13.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer14.norm1.weight with shape (928,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer14.norm1.bias with shape (928,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer14.norm1.running_mean with shape (928,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer14.norm1.running_var with shape (928,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer14.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer15.norm1.weight with shape (960,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer15.norm1.bias with shape (960,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer15.norm1.running_mean with shape (960,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer15.norm1.running_var with shape (960,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer15.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer16.norm1.weight with shape (992,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer16.norm1.bias with shape (992,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer16.norm1.running_mean with shape (992,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer16.norm1.running_var with shape (992,).
# DEBUG:onnx2keras:Found weight densenet121.features.denseblock4.denselayer16.conv2.weight with shape (32, 128, 3, 3).
# DEBUG:onnx2keras:Found weight densenet121.features.norm5.weight with shape (1024,).
# DEBUG:onnx2keras:Found weight densenet121.features.norm5.bias with shape (1024,).
# DEBUG:onnx2keras:Found weight densenet121.features.norm5.running_mean with shape (1024,).
# DEBUG:onnx2keras:Found weight densenet121.features.norm5.running_var with shape (1024,).
# DEBUG:onnx2keras:Found weight densenet121.classifier.0.weight with shape (14, 1024).
# DEBUG:onnx2keras:Found weight densenet121.classifier.0.bias with shape (14,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1161 with shape (64, 3, 7, 7).
# DEBUG:onnx2keras:Found weight onnx::Conv_1162 with shape (64,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1164 with shape (128, 64, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1165 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1167 with shape (128, 96, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1168 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1170 with shape (128, 128, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1171 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1173 with shape (128, 160, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1174 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1176 with shape (128, 192, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1177 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1179 with shape (128, 224, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1180 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1182 with shape (128, 128, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1183 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1185 with shape (128, 160, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1186 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1188 with shape (128, 192, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1189 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1191 with shape (128, 224, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1192 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1194 with shape (128, 256, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1195 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1197 with shape (128, 288, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1198 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1200 with shape (128, 320, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1201 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1203 with shape (128, 352, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1204 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1206 with shape (128, 384, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1207 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1209 with shape (128, 416, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1210 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1212 with shape (128, 448, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1213 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1215 with shape (128, 480, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1216 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1218 with shape (128, 256, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1219 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1221 with shape (128, 288, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1222 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1224 with shape (128, 320, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1225 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1227 with shape (128, 352, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1228 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1230 with shape (128, 384, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1231 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1233 with shape (128, 416, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1234 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1236 with shape (128, 448, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1237 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1239 with shape (128, 480, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1240 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1242 with shape (128, 512, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1243 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1245 with shape (128, 544, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1246 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1248 with shape (128, 576, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1249 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1251 with shape (128, 608, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1252 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1254 with shape (128, 640, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1255 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1257 with shape (128, 672, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1258 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1260 with shape (128, 704, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1261 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1263 with shape (128, 736, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1264 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1266 with shape (128, 768, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1267 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1269 with shape (128, 800, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1270 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1272 with shape (128, 832, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1273 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1275 with shape (128, 864, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1276 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1278 with shape (128, 896, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1279 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1281 with shape (128, 928, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1282 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1284 with shape (128, 960, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1285 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1287 with shape (128, 992, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1288 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1290 with shape (128, 512, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1291 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1293 with shape (128, 544, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1294 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1296 with shape (128, 576, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1297 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1299 with shape (128, 608, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1300 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1302 with shape (128, 640, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1303 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1305 with shape (128, 672, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1306 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1308 with shape (128, 704, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1309 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1311 with shape (128, 736, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1312 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1314 with shape (128, 768, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1315 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1317 with shape (128, 800, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1318 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1320 with shape (128, 832, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1321 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1323 with shape (128, 864, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1324 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1326 with shape (128, 896, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1327 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1329 with shape (128, 928, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1330 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1332 with shape (128, 960, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1333 with shape (128,).
# DEBUG:onnx2keras:Found weight onnx::Conv_1335 with shape (128, 992, 1, 1).
# DEBUG:onnx2keras:Found weight onnx::Conv_1336 with shape (128,).
# /home/berack/upo-AIContrastive/.venv_th/lib/python3.12/site-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# DEBUG:onnx2keras:Found input input with shape [3, 224, 224]
# DEBUG:onnx2keras:######
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Converting ONNX operation
# DEBUG:onnx2keras:type: Conv
# DEBUG:onnx2keras:node_name: /densenet121/features/conv0/Conv_output_0
# DEBUG:onnx2keras:node_params: {'dilations': [1, 1], 'group': 1, 'kernel_shape': [7, 7], 'pads': [3, 3, 3, 3], 'strides': [2, 2], 'change_ordering': False, 'name_policy': None}
# DEBUG:onnx2keras:...
# DEBUG:onnx2keras:Check if all inputs are available:
# DEBUG:onnx2keras:Check input 0 (name input).
# DEBUG:onnx2keras:Check input 1 (name onnx::Conv_1161).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:Check input 2 (name onnx::Conv_1162).
# DEBUG:onnx2keras:The input not found in layers / model inputs.
# DEBUG:onnx2keras:Found in weights, add as a numpy constant.
# DEBUG:onnx2keras:... found all, continue
# DEBUG:onnx2keras:conv:Conv with bias
# DEBUG:onnx2keras:conv:2D convolution
# DEBUG:onnx2keras:conv:Paddings exist, add ZeroPadding layer
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 8
#       5 onnx_model = onnx.load('densenet121.onnx')
#       7 from onnx2keras import onnx_to_keras
# ----> 8 keras_model = onnx_to_keras(onnx_model, ['input'])
#      10 # Load weights into Keras model
#      11 weights = model.state_dict()
#
# File ~/upo-AIContrastive/.venv_th/lib/python3.12/site-packages/onnx2keras/converter.py:175, in onnx_to_keras(onnx_model, input_names, input_shapes, name_policy, verbose, change_ordering)
#     172     logger.debug('... found all, continue')
#     174 keras.backend.set_image_data_format('channels_first')
# --> 175 AVAILABLE_CONVERTERS[node_type](
#     176     node,
#     177     node_params,
#     178     layers,
#     179     lambda_funcs,
#     180     node_name,
#     181     keras_names
#     182 )
#     183 if isinstance(keras_names, list):
#     184     keras_names = keras_names[0]
#
# File ~/upo-AIContrastive/.venv_th/lib/python3.12/site-packages/onnx2keras/convolution_layers.py:86, in convert_conv(node, params, layers, lambda_func, node_name, keras_name)
#      84     logger.debug('Paddings exist, add ZeroPadding layer')
#      85     padding_name = keras_name + '_pad'
# ---> 86     padding_layer = keras.layers.ZeroPadding2D(
#      87         padding=padding,
#      88         name=padding_name,
#      89         data_format='channels_first'
#      90     )
#      91     layers[padding_name] = input_0 = padding_layer(input_0)
#      93 W = W.transpose(2, 3, 1, 0)
#
# File ~/upo-AIContrastive/.venv_th/lib/python3.12/site-packages/keras/src/layers/reshaping/zero_padding2d.py:72, in ZeroPadding2D.__init__(self, padding, data_format, **kwargs)
#      71 def __init__(self, padding=(1, 1), data_format=None, **kwargs):
# ---> 72     super().__init__(**kwargs)
#      73     self.data_format = backend.standardize_data_format(data_format)
#      74     if isinstance(padding, int):
#
# File ~/upo-AIContrastive/.venv_th/lib/python3.12/site-packages/keras/src/layers/layer.py:272, in Layer.__init__(self, activity_regularizer, trainable, dtype, autocast, name, **kwargs)
#     270 BackendLayer.__init__(self)
#     271 self._lock = False
# --> 272 Operation.__init__(self, dtype=dtype, name=name)
#     273 self.activity_regularizer = regularizers.get(activity_regularizer)
#     274 input_dim_arg = kwargs.pop("input_dim", None)
#
# File ~/upo-AIContrastive/.venv_th/lib/python3.12/site-packages/keras/src/ops/operation.py:21, in Operation.__init__(self, dtype, name)
#      19     name = auto_name(self.__class__.__name__)
#      20 if not isinstance(name, str) or "/" in name:
# ---> 21     raise ValueError(
#      22         "Argument `name` must be a string and "
#      23         "cannot contain character `/`. "
#      24         f"Received: name={name} (of type {type(name)})"
#      25     )
#      26 self._dtype_policy = dtype_policies.get(dtype)
#      27 self.name = name
#
# ValueError: Argument `name` must be a string and cannot contain character `/`. Received: name=/densenet121/features/conv0/Conv_output_0_pad (of type <class 'str'>)
